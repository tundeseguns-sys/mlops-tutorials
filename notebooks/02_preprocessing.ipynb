# %%
import pandas as pd

# %%
train_df = pd.read_csv("../data/processed/train.csv")
test_df = pd.read_csv("../data/processed/test.csv")

# %%
train_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              1      No         No      16          Yes
# 1  Female              0      No         No       1           No
# 2  Female              0     Yes         No      65          Yes
# 3  Female              0      No         No       1           No
# 4    Male              1     Yes         No      36          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0               Yes             DSL            Yes           No
# 1  No phone service             DSL             No           No
# 2               Yes     Fiber optic             No          Yes
# 3  No phone service             DSL             No           No
# 4               Yes     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1               No          No          No              No  Month-to-month
# 2              Yes         Yes         Yes             Yes        Two year
# 3               No          No          No              No  Month-to-month
# 4               No          No          No             Yes  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           54.10        889.00
# 1               No           Electronic check           25.25         25.25
# 2              Yes  Bank transfer (automatic)          107.65       7082.85
# 3               No               Mailed check           24.40         24.40
# 4              Yes    Credit card (automatic)           85.25       3132.75
#
#   Churn
# 0    No
# 1    No
# 2    No
# 3    No
# 4   Yes

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5608 entries, 0 to 5607
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            5608 non-null   str
#  1   SeniorCitizen     5608 non-null   int64
#  2   Partner           5608 non-null   str
#  3   Dependents        5608 non-null   str
#  4   tenure            5608 non-null   int64
#  5   PhoneService      5608 non-null   str
#  6   MultipleLines     5608 non-null   str
#  7   InternetService   5608 non-null   str
#  8   OnlineSecurity    5608 non-null   str
#  9   OnlineBackup      5608 non-null   str
#  10  DeviceProtection  5608 non-null   str
#  11  TechSupport       5608 non-null   str
#  12  StreamingTV       5608 non-null   str
#  13  StreamingMovies   5608 non-null   str
#  14  Contract          5608 non-null   str
#  15  PaperlessBilling  5608 non-null   str
#  16  PaymentMethod     5608 non-null   str
#  17  MonthlyCharges    5608 non-null   float64
#  18  TotalCharges      5608 non-null   float64
#  19  Churn             5608 non-null   str
# dtypes: float64(2), int64(2), str(16)
# memory usage: 876.4 KB

# %%
train_df["Churn"].value_counts()
# Out:
# Churn
# No     4122
# Yes    1486
# Name: count, dtype: int64
